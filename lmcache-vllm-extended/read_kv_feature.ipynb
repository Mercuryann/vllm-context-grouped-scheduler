# %%
import numpy as np

# 加载保存的文件
data = np.load("benchmark/results/kv_features.npz")

features = data['features']
context_ids = data['context_ids']

print("Features shape:", features.shape)  # 预期输出: (14, 512)
print("Context IDs:", context_ids)        # 预期输出: ['paper_01' 'paper_02' ...]

# 查看第一个特征向量的前几个数值
print("First feature vector preview:", features[0][:5])
# Out:
# Features shape: (14, 512)
# Context IDs: ['ServerlessLLM_summary' 'SplitRPC-sigmetrics23' 'aplomb-sigcomm12'
#  'cacheblend' 'click' 'metron-nsdi18' 'nsdi20-paper-barbette'
#  'nsdi22-paper-reda_1' 'osdi24-agrawal' 'osdi24-lee' 'osdi24-sun-biao'
#  'sigcomm2023_janus' 'sigcomm24-crux' 'vllm']
# First feature vector preview: [ 0.00455622 -0.00268768  0.00222332 -0.00535897 -0.0011491 ]
